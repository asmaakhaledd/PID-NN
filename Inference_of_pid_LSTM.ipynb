# %% [markdown]
# <a href="https://colab.research.google.com/github/asmaakhaledd/PID-NN/blob/PID-Bolus/Inference_of_pid_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy pandas tensorflow
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import random
import math

# %% [markdown]
# Load model

# %%
# Load the trained model
def load_model(model_path):
    pid_model = tf.keras.models.load_model(model_path, compile=False)
    pid_model.compile(optimizer='adam', loss=tf.keras.losses.MeanSquaredError())
    return pid_model

# %% [markdown]
# Preprocess time features (cyclic encoding)

# %%
# Preprocess time features (Use timestep as timestamp)
def preprocess_time_features(timestep, glucose, weight):
    # Using cyclic encoding for time, but we will use timestep as time (1, 2, 3,...)
    hour = timestep % 24
    minute = 0  # Simulate with minute 0 for simplicity
    time_sin = np.sin(2 * np.pi * hour / 24)
    time_cos = np.cos(2 * np.pi * hour / 24)
    return [glucose - 110, glucose - random.uniform(70, 180), weight, time_sin, time_cos]

# %% [markdown]
# Prepare PID data for inference

# %%
# Prepare PID data for inference
def prepare_pid_data(timestep, glucose, weight):
    # Preprocess real-time data for the PID model
    return np.array([preprocess_time_features(timestep, glucose, weight)])

# %% [markdown]
# Adjust basal insulin dosage based on glucose and weight

# %%
def adjust_basal_insulin(glucose_level, weight, Kp, Ki, Kd, previous_glucose, cumulative_error):
    # Basal insulin rate calculation based on weight
    basal_rate_per_kg = 0.5
    TDI = 0.55 * weight  # Total daily insulin
    basal_insulin_dosage = basal_rate_per_kg * TDI  # Basal insulin dosage (50% of TDI)
    hourly_basal_rate = basal_insulin_dosage / 24  # Hourly basal rate

    # Target glucose level
    target_glucose = 100

    # Calculate the error (difference between current glucose and target)
    error = glucose_level - target_glucose

    # Proportional (Kp) term: Respond to immediate error
    adjustment_factor_proportional = Kp * error

    # Integral (Ki) term: Cumulative error over time
    cumulative_error += error  # Update cumulative error
    if cumulative_error > 10:
        cumulative_error = 10
    elif cumulative_error < -10:
        cumulative_error = -10
    adjustment_factor_integral = Ki * cumulative_error

    # Derivative (Kd) term: Rate of change in glucose
    glucose_change_rate = glucose_level - previous_glucose  # Difference between current and previous glucose levels
    adjustment_factor_derivative = Kd * glucose_change_rate

    # Total adjusted basal rate including all PID terms
    adjusted_basal_rate = hourly_basal_rate + adjustment_factor_proportional + adjustment_factor_integral + adjustment_factor_derivative

    # Apply limits to the basal rate to prevent it from becoming too low or too high
    min_basal_rate = 0.3
    max_basal_rate = 2.0
    adjusted_basal_rate = max(min_basal_rate, min(adjusted_basal_rate, max_basal_rate))


    # Return the adjusted basal rate and the updated cumulative error for next use
    return adjusted_basal_rate, cumulative_error, glucose_level

# %% [markdown]
# Bolus Calculation

# %%
def calculate_bolus(weight, glucose_level, target_glucose, meal_carbs, insulin_type='rapid'):
    # Calculate Total Daily Insulin (TDI)
    TDI = weight * 0.55  # For weight in kg

    # Calculate the Correction Factor based on insulin type
    if insulin_type == 'rapid':
        correction_factor = 1800 / TDI


    # Calculate correction dose if BG is above target
    correction_dose = 0
    if glucose_level > target_glucose:
        correction_dose = (glucose_level - target_glucose) / correction_factor

    # Calculate carb-to-insulin ratio
    carb_to_insulin_ratio = 500 / TDI

    # Calculate bolus insulin based on carbs in the meal
    bolus_for_meal = (meal_carbs / carb_to_insulin_ratio)*60

    # Total bolus insulin for the meal including correction
    total_bolus = bolus_for_meal + correction_dose

    # Limit the bolus insulin to a safe range
    # min_bolus = 0.5  # Minimum bolus insulin per meal
    # max_bolus = 10.0  # Maximum bolus insulin per meal
    # total_bolus = max(min_bolus, min(total_bolus, max_bolus))

    print(f"Timestep: {timestep}, Glucose: {glucose:.2f} mg/dL, Carbs: {meal_carbs}, Bolus for meal: {bolus_for_meal:.2f} units, Correction dose: {correction_dose:.2f} units, Total bolus: {total_bolus:.2f} units")

    return total_bolus

# %% [markdown]
# Predict insulin dosage

# %%
def predict_insulin_dosage(pid_model, glucose, weight, timestep, previous_glucose, cumulative_error):
    # Prepare input data for PID model
    X_pid_test = prepare_pid_data(timestep, glucose, weight)

    # Make prediction using the trained PID model (predicting Kp, Ki, Kd)
    predicted_pid_gains = pid_model.predict(X_pid_test)

    # Extract predicted PID gains (Kp, Ki, Kd)
    Kp, Ki, Kd = predicted_pid_gains[0]

    # Adjust basal insulin based on the predicted PID gains and glucose level
    adjusted_basal_rate, cumulative_error, previous_glucose = adjust_basal_insulin(
        glucose, weight, Kp, Ki, Kd, previous_glucose, cumulative_error
    )

    # Print the result
    print(f"\nSample {timestep}:")
    print(f"Timestep: {timestep}")
    print(f"Glucose: {glucose:.2f} mg/dL")
    print(f"Adjusted Hourly Basal Insulin: {adjusted_basal_rate:.2f} U per hour")
    print(f"Weight: {weight} kg")
    print("-" * 50)

    # Return updated values to be used in the next timestep
    return previous_glucose, cumulative_error, glucose, adjusted_basal_rate

# %% [markdown]
# Dejavu-RM property specifications

# %%
def should_deliver_insulin(glucose):
    # Rule 1: Don't deliver insulin if the glucose sensor has failed
    if  glucose <= 0 or glucose > 1000:
        print(f"irregular reading detected (Glucose = {glucose}): Pausing insulin delivery.")
        return False

    # Rule 2: Do not deliver insulin if glucose < 50 mg/dL
    if glucose < 50:
        print(f"Hypoglycemia detected (Glucose = {glucose}): Pausing insulin delivery.")
        return False

     # Rule 3: Missing or unreadable glucose value
    if glucose is None or (isinstance(glucose, float) and math.isnan(glucose)):
        print("No glucose reading available: Pausing insulin delivery.")
        return False



    return True

# %% [markdown]
# parse_test_case

# %%
def parse_test_case(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    weight = None
    sim_time = None
    meals = []

    for line in lines:
        if "Body Weight" in line:
            weight = float(line.strip().split(':')[1].split()[0])
        elif "Simulation Time" in line:
            sim_time = int(line.strip().split(':')[1].split()[0])
        elif "Meal" in line and "Time" in line:
            parts = line.strip().split(',')
            time = int(parts[0].split(':')[1].strip().split()[0])
            carbs = float(parts[1].split(':')[1].strip().split()[0])
            meals.append((time, carbs))

    return weight, sim_time, meals

# %% [markdown]
# Main

# %%
def initialize_simulation(weight):
    """
    Initializes the simulation with basic patient parameters, including
    Total Daily Insulin (TDI), daily basal limit, and other essential tracking variables.

    Args:
        weight (float): The weight of the patient.

    Returns:
        dict: A dictionary containing all the initial state variables for the simulation.
    """
    # Calculate Total Daily Insulin (TDI) as 55% of the body weight
    TDI = 0.55 * weight

    # Calculate daily basal limit as 50% of TDI (this will be used to cap basal insulin delivery)
    daily_basal_limit = 0.5 * TDI

    # Initialize the simulation state with various tracking variables
    return {
        "weight": weight,  # Store the weight of the patient
        "TDI": TDI,  # Store the calculated Total Daily Insulin
        "daily_basal_limit": daily_basal_limit,  # Store the daily basal insulin limit
        "previous_glucose": 100,  # Initialize previous glucose level (e.g., starting glucose)
        "cumulative_error": 0,  # Initialize cumulative error for PID controller
        "next_basal_timestep": 1,  # The next basal insulin delivery time step (minute)
        "basal_tracker": {},  # Tracker for basal insulin delivery per day
        "basal_rates": [],  # List to store basal insulin rates over time
        "bolus_insulin": [],  # List to store bolus insulin doses
        "carb_intake": [],  # List to store meal carbohydrate intake over time
        "infusion_values": []  # List to store infusion values (both basal and bolus insulin delivery)
    }

def check_meal(timestep, meal_schedule):
    """
    Checks if there is a meal scheduled at the current timestep + 10 minutes.

    Args:
        timestep (int): The current simulation timestep.
        meal_schedule (dict): A dictionary with the meal times and their associated carb values.

    Returns:
        float: The amount of carbs for the scheduled meal (0 if no meal is scheduled).
    """
    return meal_schedule.get(timestep - 20, 0)

def deliver_bolus(timestep, glucose, meal_carbs, sim_vars):
    """
    Delivers a bolus insulin dose based on the meal carbohydrate intake and glucose level.

    Args:
        timestep (int): The current simulation timestep.
        glucose (float): The current glucose level of the patient.
        meal_carbs (float): The number of carbs in the current meal.
        sim_vars (dict): The current simulation state variables.

    Returns:
        tuple: Returns a tuple with 0 (reset meal_carbs) and the total bolus insulin delivered.
    """
    # Calculate the bolus insulin dose based on the weight, glucose, target glucose (110), and meal carbs
    total_bolus = calculate_bolus(sim_vars["weight"], glucose, 110, meal_carbs)

    # Append the bolus insulin, carb intake, and infusion values to the simulation state
    sim_vars["bolus_insulin"].append(total_bolus)
    sim_vars["carb_intake"].append(meal_carbs)
    sim_vars["infusion_values"].append(total_bolus)

    # Reset the meal carbs to 0 (as the bolus has been delivered)
    return 0, total_bolus

def deliver_basal(timestep, glucose, pid_model, sim_vars):
    """
    Delivers a basal insulin dose based on the PID model prediction and glucose level.

    Args:
        timestep (int): The current simulation timestep.
        glucose (float): The current glucose level of the patient.
        pid_model (tf.keras.Model): The trained PID model for predicting Kp, Ki, Kd.
        sim_vars (dict): The current simulation state variables.
    """
    # Predict the insulin dosage (Kp, Ki, Kd) from the PID model
    prev_g, cum_err, _, adjusted_basal_rate = predict_insulin_dosage(
        pid_model, glucose, sim_vars["weight"], timestep,
        sim_vars["previous_glucose"], sim_vars["cumulative_error"]
    )

    # Calculate the current day from the timestep (1440 timesteps per day)
    current_day = (timestep - 1) // 1440
    tracker = sim_vars["basal_tracker"]

    # Initialize the basal tracker for the current day if it doesn't exist
    if current_day not in tracker:
        tracker[current_day] = 0

    # Convert the adjusted basal rate from units per hour to units per minute (for more precision)
    adjusted_basal_rate_per_minute = (adjusted_basal_rate / 60.0) * 15  # Account for 15-minute intervals

    # Check if adding the adjusted basal rate will exceed the daily basal limit
    if tracker[current_day] + adjusted_basal_rate_per_minute > sim_vars["daily_basal_limit"]:
        # If the limit is exceeded, cap the basal rate to the remaining allowable basal insulin
        print(f"Limit exceeded! Timestep {timestep}: Attempting to deliver {adjusted_basal_rate:.2f} U per minute, but capping it.")
        adjusted_basal_rate_per_minute = max(0, sim_vars["daily_basal_limit"] - tracker[current_day])
        print(f"Capped basal rate to {adjusted_basal_rate_per_minute:.4f} U per minute to respect daily basal limit.")

    # Update the basal tracker with the adjusted basal rate for the current day
    tracker[current_day] += adjusted_basal_rate_per_minute

    # Append the adjusted basal rate to the basal rates and infusion values
    sim_vars["basal_rates"].append(adjusted_basal_rate_per_minute)
    sim_vars["infusion_values"].append(adjusted_basal_rate_per_minute)

    # Update the previous glucose and cumulative error for the next iteration
    sim_vars["previous_glucose"] = prev_g
    sim_vars["cumulative_error"] = cum_err

    # Schedule the next basal delivery 15 timesteps ahead
    sim_vars["next_basal_timestep"] = timestep + 15

def maintain_previous(sim_vars):
    """
    Maintains the previous basal insulin delivery if no bolus or basal was delivered at the current timestep.

    Args:
        sim_vars (dict): The current simulation state variables.
    """
    # Maintain the last basal rate if no new bolus or basal insulin was delivered
    last_basal = sim_vars["basal_rates"][-1] if sim_vars["basal_rates"] else 1.0
    sim_vars["infusion_values"].append(last_basal)
    sim_vars["basal_rates"].append(last_basal)
    sim_vars["bolus_insulin"].append(0)
    sim_vars["carb_intake"].append(0)

# %%
if __name__ == "__main__":
    # Load model and test case
    # Load the trained PID model for insulin prediction
    model_path = '/content/drive/MyDrive/GP PID/opt_pid_tuning_model_2.h5'
    pid_model = load_model(model_path)  # Load the model from the given path

    # Load the test case data, including weight, simulation time, and meal schedule
    test_case_path = '/content/drive/MyDrive/GP PID/TestCases.txt'
    weight, sim_time, meals = parse_test_case(test_case_path)  # Parse test case file

    # Create a meal schedule dictionary (time: carbs) for fast lookups during simulation
    meal_schedule = {time: carbs for time, carbs in meals}

    # Initialize the simulation with the patient's weight and other state variables
    sim_vars = initialize_simulation(weight)

    # Set the initial timestep to 1 (starting point of the simulation)
    timestep = 1
    meal_carbs = 0  # Initially no meal carbs

    # Main loop to run the simulation for each timestep up to the simulation time
    while timestep <= sim_time:
        # Randomly generate the glucose level between 70 and 180 mg/dL at each timestep
        glucose = random.uniform(70, 180)

        # Check if insulin should be delivered based on glucose level
        if should_deliver_insulin(glucose):
            adjusted_basal_rate = 0  # No basal insulin if bolus is given

            # Get the carbs for the current meal (scheduled 10 minutes ahead)
            meal_carbs = check_meal(timestep, meal_schedule)
            give_bolus = meal_carbs > 0  # Determine if a bolus should be delivered
            give_basal_now = timestep == sim_vars["next_basal_timestep"] and not give_bolus  # Check if basal is due

            # If bolus needs to be delivered (i.e., meal exists)
            if give_bolus:
                # Deliver bolus insulin and reset meal_carbs
                meal_carbs, _ = deliver_bolus(timestep, glucose, meal_carbs, sim_vars)

                # Delay basal insulin delivery if it's scheduled for the current timestep
                if sim_vars["next_basal_timestep"] == timestep:
                    sim_vars["next_basal_timestep"] = timestep + 1  # Schedule the next basal insulin for 15 minutes later

            # If basal insulin is due and no bolus is needed
            elif give_basal_now:
                # Deliver basal insulin based on the PID model prediction
                deliver_basal(timestep, glucose, pid_model, sim_vars)

                # Append 0 to bolus insulin and carb intake to maintain structure
                sim_vars["bolus_insulin"].append(0)
                sim_vars["carb_intake"].append(0)

        # If no insulin needs to be delivered, maintain the previous basal rate
        else:
            maintain_previous(sim_vars)

        timestep += 1  # Move to the next timestep in the simulation

    # Print final summary of basal insulin delivery per day
    print("\n Basal insulin summary per day:")
    # Iterate through each day and print the total basal insulin delivered for that day
    for day, total in sim_vars["basal_tracker"].items():
        print(f"  Day {day + 1}: {total:.2f} U / {sim_vars['daily_basal_limit']:.2f} U")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
#
# Sample 1:
# Timestep: 1
# Glucose: 81.74 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 16:
# Timestep: 16
# Glucose: 100.58 mg/dL
# Adjusted Hourly Basal Insulin: 1.01 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 31:
# Timestep: 31
# Glucose: 94.79 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Sample 46:
# Timestep: 46
# Glucose: 173.98 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 61:
# Timestep: 61
# Glucose: 140.16 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 76:
# Timestep: 76
# Glucose: 104.28 mg/dL
# Adjusted Hourly Basal Insulin: 1.10 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Sample 91:
# Timestep: 91
# Glucose: 77.65 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Sample 106:
# Timestep: 106
# Glucose: 169.81 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Sample 121:
# Timestep: 121
# Glucose: 80.44 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Sample 136:
# Timestep: 136
# Glucose: 177.17 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 151:
# Timestep: 151
# Glucose: 118.16 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Sample 166:
# Timestep: 166
# Glucose: 106.71 mg/dL
# Adjusted Hourly Basal Insulin: 1.34 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 181:
# Timestep: 181
# Glucose: 149.43 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 196:
# Timestep: 196
# Glucose: 154.57 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#
# Sample 211:
# Timestep: 211
# Glucose: 94.30 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 226:
# Timestep: 226
# Glucose: 109.04 mg/dL
# Adjusted Hourly Basal Insulin: 1.34 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 241:
# Timestep: 241
# Glucose: 159.21 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 256:
# Timestep: 256
# Glucose: 75.45 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 271:
# Timestep: 271
# Glucose: 115.32 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Sample 286:
# Timestep: 286
# Glucose: 102.50 mg/dL
# Adjusted Hourly Basal Insulin: 1.16 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 301:
# Timestep: 301
# Glucose: 123.16 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 316:
# Timestep: 316
# Glucose: 91.65 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 331:
# Timestep: 331
# Glucose: 95.80 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 346:
# Timestep: 346
# Glucose: 141.23 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 361:
# Timestep: 361
# Glucose: 118.83 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Sample 376:
# Timestep: 376
# Glucose: 147.15 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 391:
# Timestep: 391
# Glucose: 145.87 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Sample 406:
# Timestep: 406
# Glucose: 88.76 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Sample 421:
# Timestep: 421
# Glucose: 119.68 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Sample 436:
# Timestep: 436
# Glucose: 125.88 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#
# Sample 451:
# Timestep: 451
# Glucose: 132.11 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 466:
# Timestep: 466
# Glucose: 169.91 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 481:
# Timestep: 481
# Glucose: 85.03 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Sample 496:
# Timestep: 496
# Glucose: 118.71 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 511:
# Timestep: 511
# Glucose: 71.72 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 526:
# Timestep: 526
# Glucose: 148.34 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 541:
# Timestep: 541
# Glucose: 108.94 mg/dL
# Adjusted Hourly Basal Insulin: 0.92 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 556:
# Timestep: 556
# Glucose: 130.92 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 571:
# Timestep: 571
# Glucose: 115.57 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Sample 586:
# Timestep: 586
# Glucose: 80.04 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Sample 601:
# Timestep: 601
# Glucose: 158.01 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 616:
# Timestep: 616
# Glucose: 128.53 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 631:
# Timestep: 631
# Glucose: 144.02 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 646:
# Timestep: 646
# Glucose: 87.33 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 661:
# Timestep: 661
# Glucose: 98.15 mg/dL
# Adjusted Hourly Basal Insulin: 0.66 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#
# Sample 676:
# Timestep: 676
# Glucose: 111.65 mg/dL
# Adjusted Hourly Basal Insulin: 1.60 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 691:
# Timestep: 691
# Glucose: 162.21 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 706:
# Timestep: 706
# Glucose: 102.68 mg/dL
# Adjusted Hourly Basal Insulin: 0.60 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 721:
# Timestep: 721
# Glucose: 131.67 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 736:
# Timestep: 736
# Glucose: 87.53 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 751:
# Timestep: 751
# Glucose: 177.87 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 766:
# Timestep: 766
# Glucose: 95.73 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Sample 781:
# Timestep: 781
# Glucose: 89.14 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 796:
# Timestep: 796
# Glucose: 83.55 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 811:
# Timestep: 811
# Glucose: 137.81 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 826:
# Timestep: 826
# Glucose: 110.15 mg/dL
# Adjusted Hourly Basal Insulin: 0.74 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 841:
# Timestep: 841
# Glucose: 142.28 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 856:
# Timestep: 856
# Glucose: 118.09 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 871:
# Timestep: 871
# Glucose: 159.43 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#
# Sample 886:
# Timestep: 886
# Glucose: 92.13 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#
# Sample 901:
# Timestep: 901
# Glucose: 121.79 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 916:
# Timestep: 916
# Glucose: 131.45 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 916: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.3638 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Sample 931:
# Timestep: 931
# Glucose: 94.31 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 931: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 946:
# Timestep: 946
# Glucose: 97.15 mg/dL
# Adjusted Hourly Basal Insulin: 0.53 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 946: Attempting to deliver 0.53 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 961:
# Timestep: 961
# Glucose: 109.61 mg/dL
# Adjusted Hourly Basal Insulin: 0.95 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 961: Attempting to deliver 0.95 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 976:
# Timestep: 976
# Glucose: 90.15 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 976: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 991:
# Timestep: 991
# Glucose: 76.15 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 991: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 1006:
# Timestep: 1006
# Glucose: 94.37 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1006: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 1021:
# Timestep: 1021
# Glucose: 125.21 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1021: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Sample 1036:
# Timestep: 1036
# Glucose: 121.85 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1036: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 1051:
# Timestep: 1051
# Glucose: 95.56 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1051: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 1066:
# Timestep: 1066
# Glucose: 151.76 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1066: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Sample 1081:
# Timestep: 1081
# Glucose: 152.17 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1081: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 1096:
# Timestep: 1096
# Glucose: 101.34 mg/dL
# Adjusted Hourly Basal Insulin: 0.86 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1096: Attempting to deliver 0.86 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 1111:
# Timestep: 1111
# Glucose: 118.20 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1111: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 1126:
# Timestep: 1126
# Glucose: 107.63 mg/dL
# Adjusted Hourly Basal Insulin: 1.31 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1126: Attempting to deliver 1.31 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 1141:
# Timestep: 1141
# Glucose: 82.03 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1141: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 1156:
# Timestep: 1156
# Glucose: 111.99 mg/dL
# Adjusted Hourly Basal Insulin: 1.82 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1156: Attempting to deliver 1.82 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Sample 1171:
# Timestep: 1171
# Glucose: 140.42 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1171: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 1186:
# Timestep: 1186
# Glucose: 169.45 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1186: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 1201:
# Timestep: 1201
# Glucose: 144.80 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1201: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 1216:
# Timestep: 1216
# Glucose: 90.18 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1216: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 1231:
# Timestep: 1231
# Glucose: 148.05 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1231: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 1246:
# Timestep: 1246
# Glucose: 121.41 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1246: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 1261:
# Timestep: 1261
# Glucose: 120.51 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1261: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Sample 1276:
# Timestep: 1276
# Glucose: 158.51 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1276: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Sample 1291:
# Timestep: 1291
# Glucose: 161.77 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1291: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 1306:
# Timestep: 1306
# Glucose: 123.88 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1306: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 1321:
# Timestep: 1321
# Glucose: 173.10 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1321: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 1336:
# Timestep: 1336
# Glucose: 81.54 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1336: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 1351:
# Timestep: 1351
# Glucose: 119.28 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1351: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 1366:
# Timestep: 1366
# Glucose: 78.15 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1366: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 1381:
# Timestep: 1381
# Glucose: 130.80 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1381: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 1396:
# Timestep: 1396
# Glucose: 126.38 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1396: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Sample 1411:
# Timestep: 1411
# Glucose: 124.87 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1411: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Sample 1426:
# Timestep: 1426
# Glucose: 166.05 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 1426: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#
# Sample 1441:
# Timestep: 1441
# Glucose: 96.89 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 1456:
# Timestep: 1456
# Glucose: 122.77 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Sample 1471:
# Timestep: 1471
# Glucose: 75.51 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 1486:
# Timestep: 1486
# Glucose: 151.66 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 1501:
# Timestep: 1501
# Glucose: 129.21 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#
# Sample 1516:
# Timestep: 1516
# Glucose: 119.18 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Timestep: 1520, Glucose: 92.19 mg/dL, Carbs: 20.0, Bolus for meal: 99.99 units, Correction dose: 0.00 units, Total bolus: 99.99 units
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Sample 1531:
# Timestep: 1531
# Glucose: 141.72 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#
# Sample 1546:
# Timestep: 1546
# Glucose: 137.39 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Sample 1561:
# Timestep: 1561
# Glucose: 143.89 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Sample 1576:
# Timestep: 1576
# Glucose: 133.74 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Sample 1591:
# Timestep: 1591
# Glucose: 172.15 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Sample 1606:
# Timestep: 1606
# Glucose: 119.21 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Sample 1621:
# Timestep: 1621
# Glucose: 91.36 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Sample 1636:
# Timestep: 1636
# Glucose: 84.62 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Sample 1651:
# Timestep: 1651
# Glucose: 158.77 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#
# Sample 1666:
# Timestep: 1666
# Glucose: 85.73 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#
# Sample 1681:
# Timestep: 1681
# Glucose: 97.75 mg/dL
# Adjusted Hourly Basal Insulin: 0.56 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Sample 1696:
# Timestep: 1696
# Glucose: 141.51 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#
# Sample 1711:
# Timestep: 1711
# Glucose: 147.17 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#
# Sample 1726:
# Timestep: 1726
# Glucose: 99.67 mg/dL
# Adjusted Hourly Basal Insulin: 0.90 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#
# Sample 1741:
# Timestep: 1741
# Glucose: 119.79 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#
# Sample 1756:
# Timestep: 1756
# Glucose: 148.90 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#
# Sample 1771:
# Timestep: 1771
# Glucose: 143.89 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Sample 1786:
# Timestep: 1786
# Glucose: 171.51 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Sample 1801:
# Timestep: 1801
# Glucose: 154.70 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Sample 1816:
# Timestep: 1816
# Glucose: 79.51 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Sample 1831:
# Timestep: 1831
# Glucose: 160.44 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Sample 1846:
# Timestep: 1846
# Glucose: 151.61 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Sample 1861:
# Timestep: 1861
# Glucose: 95.17 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Sample 1876:
# Timestep: 1876
# Glucose: 105.75 mg/dL
# Adjusted Hourly Basal Insulin: 1.45 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#
# Sample 1891:
# Timestep: 1891
# Glucose: 154.89 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#
# Sample 1906:
# Timestep: 1906
# Glucose: 175.70 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Sample 1921:
# Timestep: 1921
# Glucose: 78.88 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Sample 1936:
# Timestep: 1936
# Glucose: 99.10 mg/dL
# Adjusted Hourly Basal Insulin: 0.75 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#
# Sample 1951:
# Timestep: 1951
# Glucose: 85.56 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#
# Sample 1966:
# Timestep: 1966
# Glucose: 156.63 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 1981:
# Timestep: 1981
# Glucose: 80.98 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Sample 1996:
# Timestep: 1996
# Glucose: 173.08 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 2011:
# Timestep: 2011
# Glucose: 155.18 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Sample 2026:
# Timestep: 2026
# Glucose: 178.77 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Sample 2041:
# Timestep: 2041
# Glucose: 90.87 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 2056:
# Timestep: 2056
# Glucose: 89.15 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 2071:
# Timestep: 2071
# Glucose: 110.34 mg/dL
# Adjusted Hourly Basal Insulin: 1.19 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 2086:
# Timestep: 2086
# Glucose: 113.87 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 2101:
# Timestep: 2101
# Glucose: 97.29 mg/dL
# Adjusted Hourly Basal Insulin: 0.57 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 2116:
# Timestep: 2116
# Glucose: 132.59 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 2131:
# Timestep: 2131
# Glucose: 105.54 mg/dL
# Adjusted Hourly Basal Insulin: 1.18 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 2146:
# Timestep: 2146
# Glucose: 158.46 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 2161:
# Timestep: 2161
# Glucose: 103.55 mg/dL
# Adjusted Hourly Basal Insulin: 0.91 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 2176:
# Timestep: 2176
# Glucose: 172.27 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 2191:
# Timestep: 2191
# Glucose: 158.79 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 2206:
# Timestep: 2206
# Glucose: 165.02 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#
# Sample 2221:
# Timestep: 2221
# Glucose: 83.77 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 2236:
# Timestep: 2236
# Glucose: 79.40 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 2251:
# Timestep: 2251
# Glucose: 84.00 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 2266:
# Timestep: 2266
# Glucose: 90.38 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Timestep: 2270, Glucose: 82.00 mg/dL, Carbs: 75.0, Bolus for meal: 374.96 units, Correction dose: 0.00 units, Total bolus: 374.96 units
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 2281:
# Timestep: 2281
# Glucose: 71.00 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 2296:
# Timestep: 2296
# Glucose: 113.79 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 2311:
# Timestep: 2311
# Glucose: 80.29 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 2326:
# Timestep: 2326
# Glucose: 154.80 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 2341:
# Timestep: 2341
# Glucose: 132.91 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 2356:
# Timestep: 2356
# Glucose: 112.53 mg/dL
# Adjusted Hourly Basal Insulin: 1.51 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2356: Attempting to deliver 1.51 U per minute, but capping it.
# Capped basal rate to 0.1051 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 2371:
# Timestep: 2371
# Glucose: 82.97 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2371: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 2386:
# Timestep: 2386
# Glucose: 178.84 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2386: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Sample 2401:
# Timestep: 2401
# Glucose: 172.99 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2401: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Sample 2416:
# Timestep: 2416
# Glucose: 133.71 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2416: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Sample 2431:
# Timestep: 2431
# Glucose: 82.47 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2431: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 2446:
# Timestep: 2446
# Glucose: 103.91 mg/dL
# Adjusted Hourly Basal Insulin: 1.44 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2446: Attempting to deliver 1.44 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 2461:
# Timestep: 2461
# Glucose: 159.03 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2461: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#
# Sample 2476:
# Timestep: 2476
# Glucose: 84.75 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2476: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 2491:
# Timestep: 2491
# Glucose: 176.22 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2491: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Sample 2506:
# Timestep: 2506
# Glucose: 111.19 mg/dL
# Adjusted Hourly Basal Insulin: 0.75 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2506: Attempting to deliver 0.75 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 2521:
# Timestep: 2521
# Glucose: 172.48 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2521: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 2536:
# Timestep: 2536
# Glucose: 113.99 mg/dL
# Adjusted Hourly Basal Insulin: 1.74 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2536: Attempting to deliver 1.74 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 2551:
# Timestep: 2551
# Glucose: 135.39 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2551: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 2566:
# Timestep: 2566
# Glucose: 121.37 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2566: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Sample 2581:
# Timestep: 2581
# Glucose: 70.16 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2581: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Sample 2596:
# Timestep: 2596
# Glucose: 166.35 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2596: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 2611:
# Timestep: 2611
# Glucose: 176.70 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2611: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Sample 2626:
# Timestep: 2626
# Glucose: 125.05 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2626: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#
# Sample 2641:
# Timestep: 2641
# Glucose: 81.53 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2641: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 2656:
# Timestep: 2656
# Glucose: 81.80 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2656: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 2671:
# Timestep: 2671
# Glucose: 165.56 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2671: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#
# Sample 2686:
# Timestep: 2686
# Glucose: 94.90 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2686: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 2701:
# Timestep: 2701
# Glucose: 161.95 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2701: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Sample 2716:
# Timestep: 2716
# Glucose: 112.98 mg/dL
# Adjusted Hourly Basal Insulin: 1.47 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2716: Attempting to deliver 1.47 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 2731:
# Timestep: 2731
# Glucose: 142.65 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2731: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Sample 2746:
# Timestep: 2746
# Glucose: 91.65 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2746: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 2761:
# Timestep: 2761
# Glucose: 88.94 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2761: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 2776:
# Timestep: 2776
# Glucose: 160.44 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2776: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Sample 2791:
# Timestep: 2791
# Glucose: 163.14 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2791: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#
# Sample 2806:
# Timestep: 2806
# Glucose: 90.00 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2806: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# Timestep: 2820, Glucose: 90.24 mg/dL, Carbs: 40.0, Bolus for meal: 199.98 units, Correction dose: 0.00 units, Total bolus: 199.98 units
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Sample 2821:
# Timestep: 2821
# Glucose: 106.99 mg/dL
# Adjusted Hourly Basal Insulin: 1.54 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2821: Attempting to deliver 1.54 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Sample 2836:
# Timestep: 2836
# Glucose: 164.08 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2836: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 2851:
# Timestep: 2851
# Glucose: 86.81 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2851: Attempting to deliver 0.30 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 2866:
# Timestep: 2866
# Glucose: 173.23 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# Limit exceeded! Timestep 2866: Attempting to deliver 2.00 U per minute, but capping it.
# Capped basal rate to 0.0000 U per minute to respect daily basal limit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 2881:
# Timestep: 2881
# Glucose: 88.95 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 2896:
# Timestep: 2896
# Glucose: 164.99 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 2911:
# Timestep: 2911
# Glucose: 138.08 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 2926:
# Timestep: 2926
# Glucose: 163.39 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Sample 2941:
# Timestep: 2941
# Glucose: 110.47 mg/dL
# Adjusted Hourly Basal Insulin: 0.59 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 2956:
# Timestep: 2956
# Glucose: 126.91 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 2971:
# Timestep: 2971
# Glucose: 87.99 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 2986:
# Timestep: 2986
# Glucose: 110.44 mg/dL
# Adjusted Hourly Basal Insulin: 1.14 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 3001:
# Timestep: 3001
# Glucose: 131.27 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 3016:
# Timestep: 3016
# Glucose: 164.58 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Sample 3031:
# Timestep: 3031
# Glucose: 99.73 mg/dL
# Adjusted Hourly Basal Insulin: 0.55 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#
# Sample 3046:
# Timestep: 3046
# Glucose: 110.21 mg/dL
# Adjusted Hourly Basal Insulin: 1.03 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Sample 3061:
# Timestep: 3061
# Glucose: 92.42 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#
# Sample 3076:
# Timestep: 3076
# Glucose: 134.59 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#
# Sample 3091:
# Timestep: 3091
# Glucose: 135.62 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#
# Sample 3106:
# Timestep: 3106
# Glucose: 107.58 mg/dL
# Adjusted Hourly Basal Insulin: 1.17 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#
# Sample 3121:
# Timestep: 3121
# Glucose: 94.98 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#
# Sample 3136:
# Timestep: 3136
# Glucose: 103.67 mg/dL
# Adjusted Hourly Basal Insulin: 1.36 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 3151:
# Timestep: 3151
# Glucose: 78.82 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#
# Sample 3166:
# Timestep: 3166
# Glucose: 73.49 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Sample 3181:
# Timestep: 3181
# Glucose: 86.34 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Sample 3196:
# Timestep: 3196
# Glucose: 103.99 mg/dL
# Adjusted Hourly Basal Insulin: 1.32 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 3211:
# Timestep: 3211
# Glucose: 135.62 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Sample 3226:
# Timestep: 3226
# Glucose: 99.42 mg/dL
# Adjusted Hourly Basal Insulin: 0.61 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 3241:
# Timestep: 3241
# Glucose: 94.79 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#
# Sample 3256:
# Timestep: 3256
# Glucose: 146.68 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#
# Sample 3271:
# Timestep: 3271
# Glucose: 142.38 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Sample 3286:
# Timestep: 3286
# Glucose: 109.01 mg/dL
# Adjusted Hourly Basal Insulin: 1.02 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Sample 3301:
# Timestep: 3301
# Glucose: 84.86 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Sample 3316:
# Timestep: 3316
# Glucose: 136.05 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Sample 3331:
# Timestep: 3331
# Glucose: 157.44 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 3346:
# Timestep: 3346
# Glucose: 88.63 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Sample 3361:
# Timestep: 3361
# Glucose: 80.48 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Sample 3376:
# Timestep: 3376
# Glucose: 128.67 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 3391:
# Timestep: 3391
# Glucose: 124.46 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#
# Sample 3406:
# Timestep: 3406
# Glucose: 136.21 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Sample 3421:
# Timestep: 3421
# Glucose: 151.86 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 3436:
# Timestep: 3436
# Glucose: 90.28 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Sample 3451:
# Timestep: 3451
# Glucose: 86.18 mg/dL
# Adjusted Hourly Basal Insulin: 0.30 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 3466:
# Timestep: 3466
# Glucose: 127.28 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Sample 3481:
# Timestep: 3481
# Glucose: 134.14 mg/dL
# Adjusted Hourly Basal Insulin: 2.00 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Sample 3496:
# Timestep: 3496
# Glucose: 113.27 mg/dL
# Adjusted Hourly Basal Insulin: 1.72 U per hour
# Weight: 75.75 kg
# --------------------------------------------------
#
#  Basal insulin summary per day:
#   Day 1: 20.83 U / 20.83 U
#   Day 2: 20.83 U / 20.83 U
#   Day 3: 13.10 U / 20.83 U
