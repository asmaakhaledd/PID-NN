# %% [markdown]
# <a href="https://colab.research.google.com/github/asmaakhaledd/PID-NN/blob/PID-Inference/Inference_of_Opt_PID_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy pandas tensorflow
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import xml.etree.ElementTree as ET
from tensorflow.keras.models import load_model
from datetime import datetime

# %% [markdown]
# Load model

# %%
def load_model(model_path):
    # Load the model without compiling it initially
    pid_model = tf.keras.models.load_model(model_path, compile=False)
    pid_model.compile(optimizer='adam', loss=tf.keras.losses.MeanSquaredError())  # Recompile with the correct loss
    return pid_model

# %% [markdown]
# Parse XML data into DataFrame

# %%
def parse_xml(file_path):
    import xml.etree.ElementTree as ET

    tree = ET.parse(file_path)
    root = tree.getroot()
    data = []

    # Extract patient weight
    weight = float(root.get('weight', 0))  # Defaults to 0 if missing

    # Extract meal events
    meal_events = []

    meal_node = root.find('meal')
    if meal_node:
        for event in meal_node.findall('event'):
            meal_events.append({
                'timestamp': datetime.strptime(event.get('ts'), "%d-%m-%Y %H:%M:%S"),
                'carbs': float(event.get('carbs', 0))
            })
    # Process glucose levels
    for event in root.find('glucose_level'):
        timestamp = datetime.strptime(event.get('ts'), "%d-%m-%Y %H:%M:%S")
        glucose = float(event.get('value'))

        # Find closest meal within 2 hours
        meal_intake = next(
            (m['carbs'] for m in reversed(meal_events) if (timestamp - m['timestamp']).total_seconds() <= 7200),
            0.0
        )

        data.append({
            'timestamp': timestamp,
            'glucose': glucose,
            'meal_carbs': meal_intake,
            'weight': weight
        })

    df = pd.DataFrame(data)
    return df.sort_values('timestamp')

# %% [markdown]
# Preprocess time features (cyclic encoding)

# %%
def preprocess_time_features(df):
    df['hour'] = df['timestamp'].dt.hour
    df['minute'] = df['timestamp'].dt.minute
    df['time_sin'] = np.sin(2 * np.pi * df['hour'] / 24)
    df['time_cos'] = np.cos(2 * np.pi * df['hour'] / 24)
    return df.drop(['timestamp', 'hour', 'minute'], axis=1)

# %% [markdown]
# Prepare sequences for PID tuning model (input data for LSTM)

# %%
def prepare_pid_training_data(df, sequence_length=30):
    X_pid, y_pid = [], []
    for i in range(len(df) - sequence_length):
        glucose_error = df['glucose'].iloc[i] - 110
        glucose_change = df['glucose'].iloc[i] - df['glucose'].iloc[i-1] if i > 0 else 0

        Kp = 0.05 * np.log(1 + abs(glucose_error))
        Ki = 0.005 * np.log(1 + abs(glucose_error))
        Kd = 0.002 * np.log(1 + abs(glucose_change))

        X_pid.append([glucose_error, glucose_change, df['meal_carbs'].iloc[i], df['weight'].iloc[i],
                      df['time_sin'].iloc[i], df['time_cos'].iloc[i]])
        y_pid.append([Kp, Ki, Kd])

    return np.array(X_pid), np.array(y_pid)

# %% [markdown]
# Predict Insulin Dosage

# %%
def predict_insulin_dosage(model, test_df):
    # Prepare the data
    X_pid_test, _ = prepare_pid_training_data(test_df)

    # Reshape for LSTM
    X_pid_test_reshaped = X_pid_test.reshape((X_pid_test.shape[0], X_pid_test.shape[1], 1))

    # Predict PID gains
    pid_gains = model.predict(X_pid_test_reshaped)

    # Loop through samples and compute insulin dosages
    num_samples = len(X_pid_test)  # Use the length of X_pid_test, not test_df
    for i in range(num_samples):
        glucose_prediction = X_pid_test[i][0]  # Assuming glucose is the first feature in the sequence
        glucose_error = glucose_prediction - 110
        glucose_change = glucose_prediction - X_pid_test[i-1][0] if i > 0 else 0

        weight = test_df['weight'].iloc[i]  # Get weight from test dataframe
        ISF = 5000 / weight  # Estimate ISF using weight

        glucose_correction_insulin = glucose_error / ISF

        # Calculate insulin dosage using PID
        insulin_dosage = (pid_gains[i][0] * glucose_error +
                          pid_gains[i][1] * glucose_error +
                          pid_gains[i][2] * glucose_change) * 0.1
        insulin_dosage += glucose_correction_insulin

        # Apply a safe correction factor
        max_insulin = min(10 + (glucose_prediction - 110) / 10, 20)
        insulin_dosage = max(0, min(insulin_dosage + glucose_correction_insulin, max_insulin))

        print(f"Sample {i+1} - Predicted Glucose: {glucose_prediction:.2f} mg/dL")
        print(f"Recommended Insulin: {insulin_dosage:.2f} U (Safe Range)\n")

# %% [markdown]
# Main

# %%
if __name__ == "__main__":
    # Path to your saved model
    model_path = '/content/drive/MyDrive/GP PID/opt_pid_tuning_model.h5'

    # Load the model
    pid_model = load_model(model_path)

    # Test dataframe loading
    test_file = '/content/drive/MyDrive/GP PID/dataset/559-ws-testing.xml'
    test_df = parse_xml(test_file)

    # Preprocess time features
    test_df = preprocess_time_features(test_df)

    # Perform inference
    predict_insulin_dosage(pid_model, test_df)
# Out:
# Streaming output truncated to the last 5000 lines.
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 819 - Predicted Glucose: 102.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 820 - Predicted Glucose: 108.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 821 - Predicted Glucose: 109.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 822 - Predicted Glucose: 113.00 mg/dL
# Recommended Insulin: 0.20 U (Safe Range)
#
# Sample 823 - Predicted Glucose: 120.00 mg/dL
# Recommended Insulin: 0.66 U (Safe Range)
#
# Sample 824 - Predicted Glucose: 116.00 mg/dL
# Recommended Insulin: 0.39 U (Safe Range)
#
# Sample 825 - Predicted Glucose: 119.00 mg/dL
# Recommended Insulin: 0.59 U (Safe Range)
#
# Sample 826 - Predicted Glucose: 125.00 mg/dL
# Recommended Insulin: 1.00 U (Safe Range)
#
# Sample 827 - Predicted Glucose: 123.00 mg/dL
# Recommended Insulin: 0.86 U (Safe Range)
#
# Sample 828 - Predicted Glucose: 124.00 mg/dL
# Recommended Insulin: 0.93 U (Safe Range)
#
# Sample 829 - Predicted Glucose: 135.00 mg/dL
# Recommended Insulin: 1.67 U (Safe Range)
#
# Sample 830 - Predicted Glucose: 155.00 mg/dL
# Recommended Insulin: 3.05 U (Safe Range)
#
# Sample 831 - Predicted Glucose: 145.00 mg/dL
# Recommended Insulin: 2.34 U (Safe Range)
#
# Sample 832 - Predicted Glucose: 140.00 mg/dL
# Recommended Insulin: 2.00 U (Safe Range)
#
# Sample 833 - Predicted Glucose: 131.00 mg/dL
# Recommended Insulin: 1.39 U (Safe Range)
#
# Sample 834 - Predicted Glucose: 121.00 mg/dL
# Recommended Insulin: 0.72 U (Safe Range)
#
# Sample 835 - Predicted Glucose: 114.00 mg/dL
# Recommended Insulin: 0.26 U (Safe Range)
#
# Sample 836 - Predicted Glucose: 114.00 mg/dL
# Recommended Insulin: 0.26 U (Safe Range)
#
# Sample 837 - Predicted Glucose: 113.00 mg/dL
# Recommended Insulin: 0.20 U (Safe Range)
#
# Sample 838 - Predicted Glucose: 115.00 mg/dL
# Recommended Insulin: 0.33 U (Safe Range)
#
# Sample 839 - Predicted Glucose: 118.00 mg/dL
# Recommended Insulin: 0.53 U (Safe Range)
#
# Sample 840 - Predicted Glucose: 113.00 mg/dL
# Recommended Insulin: 0.20 U (Safe Range)
#
# Sample 841 - Predicted Glucose: 108.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 842 - Predicted Glucose: 107.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 843 - Predicted Glucose: 106.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 844 - Predicted Glucose: 100.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 845 - Predicted Glucose: 100.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 846 - Predicted Glucose: 107.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 847 - Predicted Glucose: 111.00 mg/dL
# Recommended Insulin: 0.07 U (Safe Range)
#
# Sample 848 - Predicted Glucose: 116.00 mg/dL
# Recommended Insulin: 0.40 U (Safe Range)
#
# Sample 849 - Predicted Glucose: 119.00 mg/dL
# Recommended Insulin: 0.59 U (Safe Range)
#
# Sample 850 - Predicted Glucose: 116.00 mg/dL
# Recommended Insulin: 0.39 U (Safe Range)
#
# Sample 851 - Predicted Glucose: 115.00 mg/dL
# Recommended Insulin: 0.33 U (Safe Range)
#
# Sample 852 - Predicted Glucose: 120.00 mg/dL
# Recommended Insulin: 0.66 U (Safe Range)
#
# Sample 853 - Predicted Glucose: 121.00 mg/dL
# Recommended Insulin: 0.73 U (Safe Range)
#
# Sample 854 - Predicted Glucose: 116.00 mg/dL
# Recommended Insulin: 0.39 U (Safe Range)
#
# Sample 855 - Predicted Glucose: 108.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 856 - Predicted Glucose: 99.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 857 - Predicted Glucose: 90.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 858 - Predicted Glucose: 84.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 859 - Predicted Glucose: 81.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 860 - Predicted Glucose: 83.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 861 - Predicted Glucose: 89.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 862 - Predicted Glucose: 93.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 863 - Predicted Glucose: 95.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 864 - Predicted Glucose: 97.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 865 - Predicted Glucose: 98.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 866 - Predicted Glucose: 90.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 867 - Predicted Glucose: 83.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 868 - Predicted Glucose: 81.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 869 - Predicted Glucose: 82.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 870 - Predicted Glucose: 78.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 871 - Predicted Glucose: 91.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 872 - Predicted Glucose: 90.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 873 - Predicted Glucose: 92.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 874 - Predicted Glucose: 91.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 875 - Predicted Glucose: 91.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 876 - Predicted Glucose: 91.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 877 - Predicted Glucose: 86.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 878 - Predicted Glucose: 80.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 879 - Predicted Glucose: 79.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 880 - Predicted Glucose: 72.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 881 - Predicted Glucose: 68.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 882 - Predicted Glucose: 69.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 883 - Predicted Glucose: 68.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 884 - Predicted Glucose: 60.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 885 - Predicted Glucose: 59.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 886 - Predicted Glucose: 58.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 887 - Predicted Glucose: 57.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 888 - Predicted Glucose: 57.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 889 - Predicted Glucose: 56.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 890 - Predicted Glucose: 55.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 891 - Predicted Glucose: 64.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 892 - Predicted Glucose: 84.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 893 - Predicted Glucose: 106.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 894 - Predicted Glucose: 122.00 mg/dL
# Recommended Insulin: 0.80 U (Safe Range)
#
# Sample 895 - Predicted Glucose: 132.00 mg/dL
# Recommended Insulin: 1.47 U (Safe Range)
#
# Sample 896 - Predicted Glucose: 143.00 mg/dL
# Recommended Insulin: 2.22 U (Safe Range)
#
# Sample 897 - Predicted Glucose: 164.00 mg/dL
# Recommended Insulin: 3.67 U (Safe Range)
#
# Sample 898 - Predicted Glucose: 178.00 mg/dL
# Recommended Insulin: 4.65 U (Safe Range)
#
# Sample 899 - Predicted Glucose: 187.00 mg/dL
# Recommended Insulin: 5.28 U (Safe Range)
#
# Sample 900 - Predicted Glucose: 198.00 mg/dL
# Recommended Insulin: 6.06 U (Safe Range)
#
# Sample 901 - Predicted Glucose: 201.00 mg/dL
# Recommended Insulin: 6.27 U (Safe Range)
#
# Sample 902 - Predicted Glucose: 200.00 mg/dL
# Recommended Insulin: 6.20 U (Safe Range)
#
# Sample 903 - Predicted Glucose: 198.00 mg/dL
# Recommended Insulin: 6.05 U (Safe Range)
#
# Sample 904 - Predicted Glucose: 197.00 mg/dL
# Recommended Insulin: 5.98 U (Safe Range)
#
# Sample 905 - Predicted Glucose: 185.00 mg/dL
# Recommended Insulin: 5.12 U (Safe Range)
#
# Sample 906 - Predicted Glucose: 171.00 mg/dL
# Recommended Insulin: 4.14 U (Safe Range)
#
# Sample 907 - Predicted Glucose: 157.00 mg/dL
# Recommended Insulin: 3.16 U (Safe Range)
#
# Sample 908 - Predicted Glucose: 146.00 mg/dL
# Recommended Insulin: 2.41 U (Safe Range)
#
# Sample 909 - Predicted Glucose: 129.00 mg/dL
# Recommended Insulin: 1.25 U (Safe Range)
#
# Sample 910 - Predicted Glucose: 109.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 911 - Predicted Glucose: 88.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 912 - Predicted Glucose: 76.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 913 - Predicted Glucose: 64.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 914 - Predicted Glucose: 50.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 915 - Predicted Glucose: 38.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 916 - Predicted Glucose: 31.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 917 - Predicted Glucose: 25.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 918 - Predicted Glucose: 24.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 919 - Predicted Glucose: 31.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 920 - Predicted Glucose: 37.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 921 - Predicted Glucose: 37.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 922 - Predicted Glucose: 34.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 923 - Predicted Glucose: 27.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 924 - Predicted Glucose: 20.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 925 - Predicted Glucose: 11.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 926 - Predicted Glucose: 4.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 927 - Predicted Glucose: -5.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 928 - Predicted Glucose: -15.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 929 - Predicted Glucose: -22.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 930 - Predicted Glucose: -30.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 931 - Predicted Glucose: -35.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 932 - Predicted Glucose: -37.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 933 - Predicted Glucose: -25.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 934 - Predicted Glucose: -20.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 935 - Predicted Glucose: -25.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 936 - Predicted Glucose: -19.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 937 - Predicted Glucose: -5.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 938 - Predicted Glucose: 13.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 939 - Predicted Glucose: 29.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 940 - Predicted Glucose: 38.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 941 - Predicted Glucose: 37.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 942 - Predicted Glucose: 34.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 943 - Predicted Glucose: 29.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 944 - Predicted Glucose: 22.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 945 - Predicted Glucose: 12.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 946 - Predicted Glucose: 3.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 947 - Predicted Glucose: -3.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 948 - Predicted Glucose: -10.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 949 - Predicted Glucose: -15.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 950 - Predicted Glucose: -20.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 951 - Predicted Glucose: -40.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 952 - Predicted Glucose: -41.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 953 - Predicted Glucose: -38.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 954 - Predicted Glucose: -30.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 955 - Predicted Glucose: -22.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 956 - Predicted Glucose: -18.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 957 - Predicted Glucose: -13.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 958 - Predicted Glucose: -10.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 959 - Predicted Glucose: -7.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 960 - Predicted Glucose: -4.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 961 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 962 - Predicted Glucose: 10.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 963 - Predicted Glucose: 20.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 964 - Predicted Glucose: 29.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 965 - Predicted Glucose: 40.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 966 - Predicted Glucose: 50.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 967 - Predicted Glucose: 59.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 968 - Predicted Glucose: 70.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 969 - Predicted Glucose: 78.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 970 - Predicted Glucose: 88.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 971 - Predicted Glucose: 99.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 972 - Predicted Glucose: 107.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 973 - Predicted Glucose: 115.00 mg/dL
# Recommended Insulin: 0.33 U (Safe Range)
#
# Sample 974 - Predicted Glucose: 126.00 mg/dL
# Recommended Insulin: 1.07 U (Safe Range)
#
# Sample 975 - Predicted Glucose: 132.00 mg/dL
# Recommended Insulin: 1.47 U (Safe Range)
#
# Sample 976 - Predicted Glucose: 134.00 mg/dL
# Recommended Insulin: 1.60 U (Safe Range)
#
# Sample 977 - Predicted Glucose: 137.00 mg/dL
# Recommended Insulin: 1.80 U (Safe Range)
#
# Sample 978 - Predicted Glucose: 137.00 mg/dL
# Recommended Insulin: 1.80 U (Safe Range)
#
# Sample 979 - Predicted Glucose: 135.00 mg/dL
# Recommended Insulin: 1.67 U (Safe Range)
#
# Sample 980 - Predicted Glucose: 133.00 mg/dL
# Recommended Insulin: 1.53 U (Safe Range)
#
# Sample 981 - Predicted Glucose: 135.00 mg/dL
# Recommended Insulin: 1.67 U (Safe Range)
#
# Sample 982 - Predicted Glucose: 137.00 mg/dL
# Recommended Insulin: 1.80 U (Safe Range)
#
# Sample 983 - Predicted Glucose: 136.00 mg/dL
# Recommended Insulin: 1.73 U (Safe Range)
#
# Sample 984 - Predicted Glucose: 136.00 mg/dL
# Recommended Insulin: 1.73 U (Safe Range)
#
# Sample 985 - Predicted Glucose: 136.00 mg/dL
# Recommended Insulin: 1.73 U (Safe Range)
#
# Sample 986 - Predicted Glucose: 135.00 mg/dL
# Recommended Insulin: 1.67 U (Safe Range)
#
# Sample 987 - Predicted Glucose: 133.00 mg/dL
# Recommended Insulin: 1.53 U (Safe Range)
#
# Sample 988 - Predicted Glucose: 129.00 mg/dL
# Recommended Insulin: 1.26 U (Safe Range)
#
# Sample 989 - Predicted Glucose: 125.00 mg/dL
# Recommended Insulin: 0.99 U (Safe Range)
#
# Sample 990 - Predicted Glucose: 119.00 mg/dL
# Recommended Insulin: 0.59 U (Safe Range)
#
# Sample 991 - Predicted Glucose: 113.00 mg/dL
# Recommended Insulin: 0.19 U (Safe Range)
#
# Sample 992 - Predicted Glucose: 106.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 993 - Predicted Glucose: 100.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 994 - Predicted Glucose: 93.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 995 - Predicted Glucose: 88.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 996 - Predicted Glucose: 83.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 997 - Predicted Glucose: 79.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 998 - Predicted Glucose: 75.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 999 - Predicted Glucose: 71.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1000 - Predicted Glucose: 67.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1001 - Predicted Glucose: 64.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1002 - Predicted Glucose: 60.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1003 - Predicted Glucose: 56.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1004 - Predicted Glucose: 56.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1005 - Predicted Glucose: 56.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1006 - Predicted Glucose: 51.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1007 - Predicted Glucose: 47.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1008 - Predicted Glucose: 44.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1009 - Predicted Glucose: 44.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1010 - Predicted Glucose: 43.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1011 - Predicted Glucose: 44.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1012 - Predicted Glucose: 43.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1013 - Predicted Glucose: 42.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1014 - Predicted Glucose: 41.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1015 - Predicted Glucose: 40.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1016 - Predicted Glucose: 38.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1017 - Predicted Glucose: 35.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1018 - Predicted Glucose: 32.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1019 - Predicted Glucose: 33.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1020 - Predicted Glucose: 34.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1021 - Predicted Glucose: 34.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1022 - Predicted Glucose: 32.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1023 - Predicted Glucose: 30.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1024 - Predicted Glucose: 29.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1025 - Predicted Glucose: 27.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1026 - Predicted Glucose: 26.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1027 - Predicted Glucose: 26.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1028 - Predicted Glucose: 27.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1029 - Predicted Glucose: 27.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1030 - Predicted Glucose: 27.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1031 - Predicted Glucose: 26.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1032 - Predicted Glucose: 25.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1033 - Predicted Glucose: 24.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1034 - Predicted Glucose: 23.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1035 - Predicted Glucose: 22.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1036 - Predicted Glucose: 22.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1037 - Predicted Glucose: 21.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1038 - Predicted Glucose: 20.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1039 - Predicted Glucose: 19.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1040 - Predicted Glucose: 17.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1041 - Predicted Glucose: 15.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1042 - Predicted Glucose: 14.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1043 - Predicted Glucose: 13.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1044 - Predicted Glucose: 12.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1045 - Predicted Glucose: 11.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1046 - Predicted Glucose: 11.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1047 - Predicted Glucose: 9.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1048 - Predicted Glucose: 8.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1049 - Predicted Glucose: 6.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1050 - Predicted Glucose: 4.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1051 - Predicted Glucose: 3.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1052 - Predicted Glucose: 3.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1053 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1054 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1055 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1056 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1057 - Predicted Glucose: 4.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1058 - Predicted Glucose: 5.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1059 - Predicted Glucose: 4.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1060 - Predicted Glucose: 4.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1061 - Predicted Glucose: 3.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1062 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1063 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1064 - Predicted Glucose: 1.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1065 - Predicted Glucose: 1.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1066 - Predicted Glucose: 1.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1067 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1068 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1069 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1070 - Predicted Glucose: 5.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1071 - Predicted Glucose: 8.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1072 - Predicted Glucose: 6.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1073 - Predicted Glucose: 7.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1074 - Predicted Glucose: 8.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1075 - Predicted Glucose: 5.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1076 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1077 - Predicted Glucose: 0.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1078 - Predicted Glucose: -1.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1079 - Predicted Glucose: -3.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1080 - Predicted Glucose: -5.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1081 - Predicted Glucose: -7.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1082 - Predicted Glucose: -8.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1083 - Predicted Glucose: -10.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1084 - Predicted Glucose: -11.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1085 - Predicted Glucose: -12.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1086 - Predicted Glucose: -9.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1087 - Predicted Glucose: -7.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1088 - Predicted Glucose: -10.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1089 - Predicted Glucose: -11.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1090 - Predicted Glucose: -12.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1091 - Predicted Glucose: -12.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1092 - Predicted Glucose: -13.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1093 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1094 - Predicted Glucose: 7.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1095 - Predicted Glucose: 10.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1096 - Predicted Glucose: 12.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1097 - Predicted Glucose: 14.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1098 - Predicted Glucose: 17.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1099 - Predicted Glucose: 20.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1100 - Predicted Glucose: 23.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1101 - Predicted Glucose: 27.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1102 - Predicted Glucose: 30.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1103 - Predicted Glucose: 34.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1104 - Predicted Glucose: 39.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1105 - Predicted Glucose: 41.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1106 - Predicted Glucose: 42.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1107 - Predicted Glucose: 43.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1108 - Predicted Glucose: 45.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1109 - Predicted Glucose: 47.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1110 - Predicted Glucose: 49.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1111 - Predicted Glucose: 56.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1112 - Predicted Glucose: 60.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1113 - Predicted Glucose: 66.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1114 - Predicted Glucose: 86.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1115 - Predicted Glucose: 98.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1116 - Predicted Glucose: 99.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1117 - Predicted Glucose: 98.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1118 - Predicted Glucose: 99.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1119 - Predicted Glucose: 100.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1120 - Predicted Glucose: 102.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1121 - Predicted Glucose: 106.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1122 - Predicted Glucose: 112.00 mg/dL
# Recommended Insulin: 0.13 U (Safe Range)
#
# Sample 1123 - Predicted Glucose: 121.00 mg/dL
# Recommended Insulin: 0.73 U (Safe Range)
#
# Sample 1124 - Predicted Glucose: 124.00 mg/dL
# Recommended Insulin: 0.93 U (Safe Range)
#
# Sample 1125 - Predicted Glucose: 120.00 mg/dL
# Recommended Insulin: 0.66 U (Safe Range)
#
# Sample 1126 - Predicted Glucose: 117.00 mg/dL
# Recommended Insulin: 0.46 U (Safe Range)
#
# Sample 1127 - Predicted Glucose: 129.00 mg/dL
# Recommended Insulin: 1.27 U (Safe Range)
#
# Sample 1128 - Predicted Glucose: 135.00 mg/dL
# Recommended Insulin: 1.67 U (Safe Range)
#
# Sample 1129 - Predicted Glucose: 132.00 mg/dL
# Recommended Insulin: 1.46 U (Safe Range)
#
# Sample 1130 - Predicted Glucose: 133.00 mg/dL
# Recommended Insulin: 1.53 U (Safe Range)
#
# Sample 1131 - Predicted Glucose: 136.00 mg/dL
# Recommended Insulin: 1.73 U (Safe Range)
#
# Sample 1132 - Predicted Glucose: 138.00 mg/dL
# Recommended Insulin: 1.87 U (Safe Range)
#
# Sample 1133 - Predicted Glucose: 139.00 mg/dL
# Recommended Insulin: 1.94 U (Safe Range)
#
# Sample 1134 - Predicted Glucose: 138.00 mg/dL
# Recommended Insulin: 1.87 U (Safe Range)
#
# Sample 1135 - Predicted Glucose: 137.00 mg/dL
# Recommended Insulin: 1.80 U (Safe Range)
#
# Sample 1136 - Predicted Glucose: 139.00 mg/dL
# Recommended Insulin: 1.94 U (Safe Range)
#
# Sample 1137 - Predicted Glucose: 149.00 mg/dL
# Recommended Insulin: 2.63 U (Safe Range)
#
# Sample 1138 - Predicted Glucose: 154.00 mg/dL
# Recommended Insulin: 2.97 U (Safe Range)
#
# Sample 1139 - Predicted Glucose: 157.00 mg/dL
# Recommended Insulin: 3.17 U (Safe Range)
#
# Sample 1140 - Predicted Glucose: 161.00 mg/dL
# Recommended Insulin: 3.45 U (Safe Range)
#
# Sample 1141 - Predicted Glucose: 164.00 mg/dL
# Recommended Insulin: 3.66 U (Safe Range)
#
# Sample 1142 - Predicted Glucose: 169.00 mg/dL
# Recommended Insulin: 4.01 U (Safe Range)
#
# Sample 1143 - Predicted Glucose: 175.00 mg/dL
# Recommended Insulin: 4.43 U (Safe Range)
#
# Sample 1144 - Predicted Glucose: 177.00 mg/dL
# Recommended Insulin: 4.57 U (Safe Range)
#
# Sample 1145 - Predicted Glucose: 180.00 mg/dL
# Recommended Insulin: 4.78 U (Safe Range)
#
# Sample 1146 - Predicted Glucose: 181.00 mg/dL
# Recommended Insulin: 4.85 U (Safe Range)
#
# Sample 1147 - Predicted Glucose: 177.00 mg/dL
# Recommended Insulin: 4.56 U (Safe Range)
#
# Sample 1148 - Predicted Glucose: 176.00 mg/dL
# Recommended Insulin: 4.49 U (Safe Range)
#
# Sample 1149 - Predicted Glucose: 178.00 mg/dL
# Recommended Insulin: 4.64 U (Safe Range)
#
# Sample 1150 - Predicted Glucose: 171.00 mg/dL
# Recommended Insulin: 4.14 U (Safe Range)
#
# Sample 1151 - Predicted Glucose: 164.00 mg/dL
# Recommended Insulin: 3.65 U (Safe Range)
#
# Sample 1152 - Predicted Glucose: 162.00 mg/dL
# Recommended Insulin: 3.52 U (Safe Range)
#
# Sample 1153 - Predicted Glucose: 152.00 mg/dL
# Recommended Insulin: 2.82 U (Safe Range)
#
# Sample 1154 - Predicted Glucose: 148.00 mg/dL
# Recommended Insulin: 2.55 U (Safe Range)
#
# Sample 1155 - Predicted Glucose: 132.00 mg/dL
# Recommended Insulin: 1.45 U (Safe Range)
#
# Sample 1156 - Predicted Glucose: 113.00 mg/dL
# Recommended Insulin: 0.19 U (Safe Range)
#
# Sample 1157 - Predicted Glucose: 97.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1158 - Predicted Glucose: 85.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1159 - Predicted Glucose: 75.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1160 - Predicted Glucose: 65.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1161 - Predicted Glucose: 54.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1162 - Predicted Glucose: 46.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1163 - Predicted Glucose: 40.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1164 - Predicted Glucose: 28.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1165 - Predicted Glucose: 14.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1166 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1167 - Predicted Glucose: -5.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1168 - Predicted Glucose: -10.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1169 - Predicted Glucose: -14.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1170 - Predicted Glucose: -20.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1171 - Predicted Glucose: -25.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1172 - Predicted Glucose: -30.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1173 - Predicted Glucose: -34.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1174 - Predicted Glucose: -37.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1175 - Predicted Glucose: -38.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1176 - Predicted Glucose: -38.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1177 - Predicted Glucose: -37.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1178 - Predicted Glucose: -36.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1179 - Predicted Glucose: -37.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1180 - Predicted Glucose: -38.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1181 - Predicted Glucose: -37.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1182 - Predicted Glucose: -35.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1183 - Predicted Glucose: -32.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1184 - Predicted Glucose: -30.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1185 - Predicted Glucose: -23.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1186 - Predicted Glucose: -15.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1187 - Predicted Glucose: -12.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1188 - Predicted Glucose: -11.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1189 - Predicted Glucose: -11.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1190 - Predicted Glucose: -10.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1191 - Predicted Glucose: -8.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1192 - Predicted Glucose: -2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1193 - Predicted Glucose: 3.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1194 - Predicted Glucose: 6.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1195 - Predicted Glucose: 11.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1196 - Predicted Glucose: 16.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1197 - Predicted Glucose: 20.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1198 - Predicted Glucose: 25.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1199 - Predicted Glucose: 31.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1200 - Predicted Glucose: 38.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1201 - Predicted Glucose: 46.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1202 - Predicted Glucose: 49.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1203 - Predicted Glucose: 51.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1204 - Predicted Glucose: 53.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1205 - Predicted Glucose: 54.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1206 - Predicted Glucose: 58.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1207 - Predicted Glucose: 62.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1208 - Predicted Glucose: 65.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1209 - Predicted Glucose: 70.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1210 - Predicted Glucose: 74.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1211 - Predicted Glucose: 74.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1212 - Predicted Glucose: 74.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1213 - Predicted Glucose: 74.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1214 - Predicted Glucose: 73.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1215 - Predicted Glucose: 73.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1216 - Predicted Glucose: 75.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1217 - Predicted Glucose: 77.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1218 - Predicted Glucose: 77.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1219 - Predicted Glucose: 77.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1220 - Predicted Glucose: 74.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1221 - Predicted Glucose: 72.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1222 - Predicted Glucose: 70.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1223 - Predicted Glucose: 64.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1224 - Predicted Glucose: 61.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1225 - Predicted Glucose: 58.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1226 - Predicted Glucose: 54.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1227 - Predicted Glucose: 52.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1228 - Predicted Glucose: 49.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1229 - Predicted Glucose: 46.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1230 - Predicted Glucose: 41.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1231 - Predicted Glucose: 38.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1232 - Predicted Glucose: 37.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1233 - Predicted Glucose: 38.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1234 - Predicted Glucose: 36.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1235 - Predicted Glucose: 32.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1236 - Predicted Glucose: 28.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1237 - Predicted Glucose: 24.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1238 - Predicted Glucose: 20.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1239 - Predicted Glucose: 18.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1240 - Predicted Glucose: 19.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1241 - Predicted Glucose: 24.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1242 - Predicted Glucose: 30.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1243 - Predicted Glucose: 33.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1244 - Predicted Glucose: 34.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1245 - Predicted Glucose: 34.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1246 - Predicted Glucose: 35.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1247 - Predicted Glucose: 39.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1248 - Predicted Glucose: 41.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1249 - Predicted Glucose: 45.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1250 - Predicted Glucose: 47.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1251 - Predicted Glucose: 51.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1252 - Predicted Glucose: 52.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1253 - Predicted Glucose: 53.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1254 - Predicted Glucose: 52.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1255 - Predicted Glucose: -21.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1256 - Predicted Glucose: -19.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1257 - Predicted Glucose: -18.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1258 - Predicted Glucose: -15.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1259 - Predicted Glucose: -10.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1260 - Predicted Glucose: -6.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1261 - Predicted Glucose: -2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1262 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1263 - Predicted Glucose: 5.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1264 - Predicted Glucose: 6.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1265 - Predicted Glucose: 7.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1266 - Predicted Glucose: 7.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1267 - Predicted Glucose: 8.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1268 - Predicted Glucose: 8.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1269 - Predicted Glucose: 7.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1270 - Predicted Glucose: 6.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1271 - Predicted Glucose: 5.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1272 - Predicted Glucose: 6.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1273 - Predicted Glucose: 6.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1274 - Predicted Glucose: 6.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1275 - Predicted Glucose: 7.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1276 - Predicted Glucose: 7.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1277 - Predicted Glucose: 8.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1278 - Predicted Glucose: 8.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1279 - Predicted Glucose: 8.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1280 - Predicted Glucose: 7.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1281 - Predicted Glucose: 6.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1282 - Predicted Glucose: 6.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1283 - Predicted Glucose: 6.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1284 - Predicted Glucose: 5.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1285 - Predicted Glucose: 4.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1286 - Predicted Glucose: 3.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1287 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1288 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1289 - Predicted Glucose: 0.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1290 - Predicted Glucose: 0.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1291 - Predicted Glucose: -1.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1292 - Predicted Glucose: -1.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1293 - Predicted Glucose: -2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1294 - Predicted Glucose: -2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1295 - Predicted Glucose: -1.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1296 - Predicted Glucose: 3.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1297 - Predicted Glucose: 1.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1298 - Predicted Glucose: -4.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1299 - Predicted Glucose: -7.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1300 - Predicted Glucose: -10.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1301 - Predicted Glucose: -13.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1302 - Predicted Glucose: -15.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1303 - Predicted Glucose: -17.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1304 - Predicted Glucose: -18.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1305 - Predicted Glucose: -19.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1306 - Predicted Glucose: -20.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1307 - Predicted Glucose: -21.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1308 - Predicted Glucose: -22.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1309 - Predicted Glucose: -23.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1310 - Predicted Glucose: -23.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1311 - Predicted Glucose: -24.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1312 - Predicted Glucose: -24.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1313 - Predicted Glucose: -25.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1314 - Predicted Glucose: -26.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1315 - Predicted Glucose: -26.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1316 - Predicted Glucose: -25.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1317 - Predicted Glucose: -24.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1318 - Predicted Glucose: -24.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1319 - Predicted Glucose: -24.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1320 - Predicted Glucose: -24.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1321 - Predicted Glucose: -24.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1322 - Predicted Glucose: -23.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1323 - Predicted Glucose: -23.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1324 - Predicted Glucose: -23.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1325 - Predicted Glucose: -24.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1326 - Predicted Glucose: -24.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1327 - Predicted Glucose: -24.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1328 - Predicted Glucose: -25.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1329 - Predicted Glucose: -25.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1330 - Predicted Glucose: -25.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1331 - Predicted Glucose: -25.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1332 - Predicted Glucose: -26.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1333 - Predicted Glucose: -27.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1334 - Predicted Glucose: -28.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1335 - Predicted Glucose: -28.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1336 - Predicted Glucose: -27.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1337 - Predicted Glucose: -27.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1338 - Predicted Glucose: -27.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1339 - Predicted Glucose: -27.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1340 - Predicted Glucose: -28.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1341 - Predicted Glucose: -28.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1342 - Predicted Glucose: -30.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1343 - Predicted Glucose: -32.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1344 - Predicted Glucose: -31.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1345 - Predicted Glucose: -31.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1346 - Predicted Glucose: -32.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1347 - Predicted Glucose: -33.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1348 - Predicted Glucose: -35.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1349 - Predicted Glucose: -36.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1350 - Predicted Glucose: -37.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1351 - Predicted Glucose: -38.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1352 - Predicted Glucose: -38.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1353 - Predicted Glucose: -39.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1354 - Predicted Glucose: -39.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1355 - Predicted Glucose: -38.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1356 - Predicted Glucose: -37.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1357 - Predicted Glucose: -37.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1358 - Predicted Glucose: -35.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1359 - Predicted Glucose: -33.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1360 - Predicted Glucose: -34.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1361 - Predicted Glucose: -34.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1362 - Predicted Glucose: -33.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1363 - Predicted Glucose: -34.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1364 - Predicted Glucose: -33.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1365 - Predicted Glucose: -30.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1366 - Predicted Glucose: -29.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1367 - Predicted Glucose: -27.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1368 - Predicted Glucose: -25.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 1369 - Predicted Glucose: -23.00 mg/dL
# ...
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2302 - Predicted Glucose: 74.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2303 - Predicted Glucose: 74.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2304 - Predicted Glucose: 72.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2305 - Predicted Glucose: 70.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2306 - Predicted Glucose: 68.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2307 - Predicted Glucose: 65.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2308 - Predicted Glucose: 63.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2309 - Predicted Glucose: 60.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2310 - Predicted Glucose: 59.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2311 - Predicted Glucose: 59.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2312 - Predicted Glucose: 59.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2313 - Predicted Glucose: 58.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2314 - Predicted Glucose: 57.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2315 - Predicted Glucose: 55.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2316 - Predicted Glucose: 54.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2317 - Predicted Glucose: 53.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2318 - Predicted Glucose: 53.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2319 - Predicted Glucose: 53.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2320 - Predicted Glucose: 52.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2321 - Predicted Glucose: 53.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2322 - Predicted Glucose: 54.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2323 - Predicted Glucose: 54.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2324 - Predicted Glucose: 54.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2325 - Predicted Glucose: 52.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2326 - Predicted Glucose: 51.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2327 - Predicted Glucose: 51.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2328 - Predicted Glucose: 52.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2329 - Predicted Glucose: 52.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2330 - Predicted Glucose: 52.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2331 - Predicted Glucose: 52.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2332 - Predicted Glucose: 52.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2333 - Predicted Glucose: 52.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2334 - Predicted Glucose: 53.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2335 - Predicted Glucose: 52.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2336 - Predicted Glucose: 52.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2337 - Predicted Glucose: 51.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2338 - Predicted Glucose: 51.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2339 - Predicted Glucose: 51.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2340 - Predicted Glucose: 50.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2341 - Predicted Glucose: 52.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2342 - Predicted Glucose: 51.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2343 - Predicted Glucose: 50.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2344 - Predicted Glucose: 49.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2345 - Predicted Glucose: 49.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2346 - Predicted Glucose: 47.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2347 - Predicted Glucose: 44.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2348 - Predicted Glucose: 41.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2349 - Predicted Glucose: 40.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2350 - Predicted Glucose: 45.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2351 - Predicted Glucose: 60.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2352 - Predicted Glucose: 75.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2353 - Predicted Glucose: 84.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2354 - Predicted Glucose: 90.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2355 - Predicted Glucose: 94.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2356 - Predicted Glucose: 95.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2357 - Predicted Glucose: 95.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2358 - Predicted Glucose: 96.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2359 - Predicted Glucose: 97.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2360 - Predicted Glucose: 97.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2361 - Predicted Glucose: 98.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2362 - Predicted Glucose: 98.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2363 - Predicted Glucose: 99.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2364 - Predicted Glucose: 98.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2365 - Predicted Glucose: 98.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2366 - Predicted Glucose: 98.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2367 - Predicted Glucose: 97.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2368 - Predicted Glucose: 96.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2369 - Predicted Glucose: 94.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2370 - Predicted Glucose: 92.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2371 - Predicted Glucose: 92.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2372 - Predicted Glucose: 91.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2373 - Predicted Glucose: 90.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2374 - Predicted Glucose: 117.00 mg/dL
# Recommended Insulin: 0.48 U (Safe Range)
#
# Sample 2375 - Predicted Glucose: 113.00 mg/dL
# Recommended Insulin: 0.20 U (Safe Range)
#
# Sample 2376 - Predicted Glucose: 112.00 mg/dL
# Recommended Insulin: 0.13 U (Safe Range)
#
# Sample 2377 - Predicted Glucose: 110.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2378 - Predicted Glucose: 109.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2379 - Predicted Glucose: 109.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2380 - Predicted Glucose: 109.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2381 - Predicted Glucose: 107.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2382 - Predicted Glucose: 106.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2383 - Predicted Glucose: 107.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2384 - Predicted Glucose: 107.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2385 - Predicted Glucose: 106.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2386 - Predicted Glucose: 104.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2387 - Predicted Glucose: 102.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2388 - Predicted Glucose: 100.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2389 - Predicted Glucose: 97.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2390 - Predicted Glucose: 93.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2391 - Predicted Glucose: 88.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2392 - Predicted Glucose: 83.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2393 - Predicted Glucose: 77.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2394 - Predicted Glucose: 72.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2395 - Predicted Glucose: 67.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2396 - Predicted Glucose: 61.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2397 - Predicted Glucose: 56.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2398 - Predicted Glucose: 52.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2399 - Predicted Glucose: 48.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2400 - Predicted Glucose: 43.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2401 - Predicted Glucose: 38.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2402 - Predicted Glucose: 33.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2403 - Predicted Glucose: 29.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2404 - Predicted Glucose: 26.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2405 - Predicted Glucose: 24.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2406 - Predicted Glucose: 21.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2407 - Predicted Glucose: 19.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2408 - Predicted Glucose: 15.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2409 - Predicted Glucose: 13.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2410 - Predicted Glucose: 11.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2411 - Predicted Glucose: 10.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2412 - Predicted Glucose: 8.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2413 - Predicted Glucose: 6.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2414 - Predicted Glucose: 5.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2415 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2416 - Predicted Glucose: -1.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2417 - Predicted Glucose: -5.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2418 - Predicted Glucose: -8.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2419 - Predicted Glucose: -10.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2420 - Predicted Glucose: -9.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2421 - Predicted Glucose: -6.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2422 - Predicted Glucose: -4.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2423 - Predicted Glucose: -2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2424 - Predicted Glucose: 0.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2425 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2426 - Predicted Glucose: 3.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2427 - Predicted Glucose: 3.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2428 - Predicted Glucose: 3.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2429 - Predicted Glucose: 1.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2430 - Predicted Glucose: 2.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2431 - Predicted Glucose: 5.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2432 - Predicted Glucose: 8.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2433 - Predicted Glucose: 9.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2434 - Predicted Glucose: 10.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2435 - Predicted Glucose: 13.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2436 - Predicted Glucose: 14.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2437 - Predicted Glucose: 15.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2438 - Predicted Glucose: 15.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2439 - Predicted Glucose: 18.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2440 - Predicted Glucose: 21.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2441 - Predicted Glucose: 25.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2442 - Predicted Glucose: 30.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2443 - Predicted Glucose: 34.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2444 - Predicted Glucose: 36.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2445 - Predicted Glucose: 41.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2446 - Predicted Glucose: 47.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2447 - Predicted Glucose: 52.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2448 - Predicted Glucose: 58.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2449 - Predicted Glucose: 62.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2450 - Predicted Glucose: 67.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2451 - Predicted Glucose: 71.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2452 - Predicted Glucose: 75.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2453 - Predicted Glucose: 78.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2454 - Predicted Glucose: 82.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2455 - Predicted Glucose: 85.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2456 - Predicted Glucose: 89.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2457 - Predicted Glucose: 92.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2458 - Predicted Glucose: 95.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2459 - Predicted Glucose: 98.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2460 - Predicted Glucose: 100.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2461 - Predicted Glucose: 102.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2462 - Predicted Glucose: 103.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2463 - Predicted Glucose: 104.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2464 - Predicted Glucose: 104.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2465 - Predicted Glucose: 104.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2466 - Predicted Glucose: 103.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2467 - Predicted Glucose: 102.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2468 - Predicted Glucose: 100.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2469 - Predicted Glucose: 99.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2470 - Predicted Glucose: 97.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2471 - Predicted Glucose: 96.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2472 - Predicted Glucose: 94.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2473 - Predicted Glucose: 93.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2474 - Predicted Glucose: 91.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2475 - Predicted Glucose: 89.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2476 - Predicted Glucose: 88.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2477 - Predicted Glucose: 86.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2478 - Predicted Glucose: 85.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2479 - Predicted Glucose: 83.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2480 - Predicted Glucose: 82.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2481 - Predicted Glucose: 81.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2482 - Predicted Glucose: 80.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2483 - Predicted Glucose: 80.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
#
# Sample 2484 - Predicted Glucose: 79.00 mg/dL
# Recommended Insulin: 0.00 U (Safe Range)
